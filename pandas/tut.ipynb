# %%
import numpy as np;
import pandas as pd

# %%
dict1 = {
    "name":['harry','rohen','sachin','shubham','om'],
    "marks":[92,42,82,75,67],
    "city":['malkapur','pune','akola','mumbai','malkapur'],
    "rollno":[23,66,21,77,88]
}

# %%
df = pd.DataFrame(dict1)

# %%
df.loc
# Out:
#       name  marks      city  rollno
# 0    harry     92  malkapur      23
# 1    rohen     42      pune      66
# 2   sachin     82     akola      21
# 3  shubham     75    mumbai      77
# 4       om     67  malkapur      88

# %%
df.columns
# Out:
# Index(['name', 'marks', 'city', 'rollno'], dtype='object')

# %%
type(df.marks[2])
# Out:
# numpy.int64

# %%
df.to_csv("friend.csv")

# %%
df.to_csv("with_no_index.csv",index=False)

# %%
df.head
# Out:
# <bound method NDFrame.head of       name  marks      city
# 0    harry     92  malkapur
# 1    rohen     42      pune
# 2   skillf     82     akola
# 3  shubham     75    mumbai>

# %%
df.tail
# Out:
# <bound method NDFrame.tail of       name  marks      city
# 0    harry     92  malkapur
# 1    rohen     42      pune
# 2   skillf     82     akola
# 3  shubham     75    mumbai>

# %%
df.head(2)
# Out:
#     name  marks      city
# 0  harry     92  malkapur
# 1  rohen     42      pune

# %%
df.tail(2)
# Out:
#       name  marks    city
# 2   skillf     82   akola
# 3  shubham     75  mumbai

# %%
df.describe()
# Out:
#            marks
# count   4.000000
# mean   72.750000
# std    21.654484
# min    42.000000
# 25%    66.750000
# 50%    78.500000
# 75%    84.500000
# max    92.000000

# %%
heart = pd.read_csv('heart.csv')

# %%
heart
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Age  Sex     ChestPain  RestBP  \
# 0           0             0               1   63    1       typical     145
# 1           1             1               2   67    1  asymptomatic     160
# 2           2             2               3   67    1  asymptomatic     120
# 3           3             3               4   37    1    nonanginal     130
# 4           4             4               5   41    0    nontypical     130
# 5           5             5               6   56    1    nontypical     120
# 6           6             6               7   62    0  asymptomatic     140
# 7           7             7               8   57    0  asymptomatic     120
# 8           8             8               9   63    1  asymptomatic     130
# 9           9             9              10   53    1  asymptomatic     140
#
#    Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  Slope  Ca        Thal  AHD
# ...

# %%
heart['MaxHR'][1]=10
heart
# Out:
# <ipython-input-38-49bec89d4f84>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heart['MaxHR'][1]=10
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Age  Sex     ChestPain  RestBP  \
# 0           0             0               1   63    1       typical     145
# 1           1             1               2   67    1  asymptomatic     160
# 2           2             2               3   67    1  asymptomatic     120
# 3           3             3               4   37    1    nonanginal     130
# 4           4             4               5   41    0    nontypical     130
# 5           5             5               6   56    1    nontypical     120
# 6           6             6               7   62    0  asymptomatic     140
# ...

# %%
heart
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Age  Sex     ChestPain  RestBP  \
# 0           0             0               1   63    1       typical     145
# 1           1             1               2   67    1  asymptomatic     160
# 2           2             2               3   67    1  asymptomatic     120
# 3           3             3               4   37    1    nonanginal     130
# 4           4             4               5   41    0    nontypical     130
# 5           5             5               6   56    1    nontypical     120
# 6           6             6               7   62    0  asymptomatic     140
# 7           7             7               8   57    0  asymptomatic     120
# 8           8             8               9   63    1  asymptomatic     130
# 9           9             9              10   53    1  asymptomatic     140
#
#    Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  Slope  Ca        Thal  AHD
# ...

# %%
heart.to_csv('heart.csv')

# %%
heart.describe()
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1        Age        Sex  \
# count    10.00000      10.00000        10.00000  10.000000  10.000000
# mean      4.50000       4.50000         5.50000  56.600000   0.700000
# std       3.02765       3.02765         3.02765  10.373042   0.483046
# min       0.00000       0.00000         1.00000  37.000000   0.000000
# 25%       2.25000       2.25000         3.25000  53.750000   0.250000
# 50%       4.50000       4.50000         5.50000  59.500000   1.000000
# 75%       6.75000       6.75000         7.75000  63.000000   1.000000
# max       9.00000       9.00000        10.00000  67.000000   1.000000
#
#            RestBP        Chol        Fbs    RestECG       MaxHR      ExAng  \
# count   10.000000   10.000000  10.000000  10.000000   10.000000  10.000000
# mean   133.500000  251.700000   0.200000   1.400000  154.100000   0.400000
# std     12.920698   44.314658   0.421637   0.966092   25.194576   0.516398
# ...

# %%
heart.dtypes
# Out:
# Unnamed: 0          int64
# Unnamed: 0.1        int64
# Unnamed: 0.1.1      int64
# Age                 int64
# Sex                 int64
# ChestPain          object
# RestBP              int64
# Chol                int64
# Fbs                 int64
# RestECG             int64
# MaxHR               int64
# ExAng               int64
# Oldpeak           float64
# Slope               int64
# Ca                  int64
# Thal               object
# AHD                object
# dtype: object

# %%
heart
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Age  Sex     ChestPain  RestBP  \
# 0           0             0               1   63    1       typical     145
# 1           1             1               2   67    1  asymptomatic     160
# 2           2             2               3   67    1  asymptomatic     120
# 3           3             3               4   37    1    nonanginal     130
# 4           4             4               5   41    0    nontypical     130
# 5           5             5               6   56    1    nontypical     120
# 6           6             6               7   62    0  asymptomatic     140
# 7           7             7               8   57    0  asymptomatic     120
# 8           8             8               9   63    1  asymptomatic     130
# 9           9             9              10   53    1  asymptomatic     140
#
#    Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  Slope  Ca        Thal  AHD
# ...

# %%
heart.head
# Out:
# <bound method NDFrame.head of    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Age  Sex     ChestPain  RestBP  \
# 0           0             0               1   63    1       typical     145
# 1           1             1               2   67    1  asymptomatic     160
# 2           2             2               3   67    1  asymptomatic     120
# 3           3             3               4   37    1    nonanginal     130
# 4           4             4               5   41    0    nontypical     130
# 5           5             5               6   56    1    nontypical     120
# 6           6             6               7   62    0  asymptomatic     140
# 7           7             7               8   57    0  asymptomatic     120
# 8           8             8               9   63    1  asymptomatic     130
# 9           9             9              10   53    1  asymptomatic     140
#
#    Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  Slope  Ca        Thal  AHD
# ...

# %%
type(heart)
# Out:
# pandas.core.frame.DataFrame

# %%
heart.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
df
# Out:
#       name  marks      city
# 0    harry     92  malkapur
# 1    rohen     42      pune
# 2   skillf     82     akola
# 3  shubham     75    mumbai

# %%
df.T
# Out:
#               0      1       2        3
# name      harry  rohen  skillf  shubham
# marks        92     42      82       75
# city   malkapur   pune   akola   mumbai

# %%
df.sort_index(axis=0,ascending=False)
# Out:
#       name  marks      city
# 3  shubham     75    mumbai
# 2   skillf     82     akola
# 1    rohen     42      pune
# 0    harry     92  malkapur

# %%
df.sort_index(axis=0,ascending=True)
# Out:
#       name  marks      city
# 0    harry     92  malkapur
# 1    rohen     42      pune
# 2   skillf     82     akola
# 3  shubham     75    mumbai

# %%
df['name']
# Out:
# 0      harry
# 1      rohen
# 2     skillf
# 3    shubham
# Name: name, dtype: object

# %%
type(df['name'])
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
newdf = df

# %%
newdf
# Out:
#       name  marks      city
# 0    harry     92  malkapur
# 1    rohen     42      pune
# 2   skillf     82     akola
# 3  shubham     75    mumbai

# %%
newdf['name'][2]='karan'
# Out:
# <ipython-input-40-87dd7c27127d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf['name'][2]='karan'

# %%
newdf
# Out:
#       name  marks      city
# 0    harry     92  malkapur
# 1    rohen     42      pune
# 2    karan     82     akola
# 3  shubham     75    mumbai

# %%
df
# Out:
#       name  marks      city
# 0    harry     92  malkapur
# 1    rohen     42      pune
# 2    karan     82     akola
# 3  shubham     75    mumbai

# %%
newdf_copy = df.copy()

# %%
newdf_copy
# Out:
#       name  marks      city
# 0    harry     92  malkapur
# 1    rohen     42      pune
# 2    karan     82     akola
# 3  shubham     75    mumbai

# %%
newdf_copy['name'][2]='joker'
# Out:
# <ipython-input-53-1cebb6a45cb6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf_copy['name'][2]='joker'

# %%
newdf_copy
# Out:
#       name  marks      city
# 0    harry     92  malkapur
# 1    rohen     42      pune
# 2    joker     82     akola
# 3  shubham     75    mumbai

# %%
df
# Out:
#       name  marks      city
# 0    harry     92  malkapur
# 1    rohen     42      pune
# 2    karan     82     akola
# 3  shubham     75    mumbai

# %%
newdf.loc[2,'marks'] = 100 #change value

# %%
newdf.loc[2,3] = 4

# %%
newdf
# Out:
#       name  marks      city    3
# 0    harry     92  malkapur  NaN
# 1    rohen     42      pune  NaN
# 2    karan    100     akola  4.0
# 3  shubham     75    mumbai  NaN

# %%
newdf = newdf.drop(3,axis=1) #return df

# %%
newdf
# Out:
#       name  marks      city
# 0    harry     92  malkapur
# 1    rohen     42      pune
# 2    karan    100     akola
# 3  shubham     75    mumbai

# %%
newdf.loc[[1,2],['name','marks']] #does not change just return df
# Out:
#     name  marks
# 1  rohen     42
# 2  karan    100

# %%
newdf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26812/3064484622.py in <module>
# ----> 1 newdf
#
# NameError: name 'newdf' is not defined

# %%
newdf.loc[:,:]
# Out:
#       name  marks      city
# 0    harry     92  malkapur
# 1    rohen     42      pune
# 2    karan    100     akola
# 3  shubham     75    mumbai

# %%
newdf.loc[[1,2],:]
# Out:
#     name  marks   city
# 1  rohen     42   pune
# 2  karan    100  akola

# %%
newdf.loc[(newdf['marks']<=75)]
# Out:
#       name  marks    city
# 1    rohen     42    pune
# 3  shubham     75  mumbai

# %%
newdf.loc[(newdf['marks']<=75 ) & (newdf['city']=='mumbai')]
# Out:
#       name  marks    city
# 3  shubham     75  mumbai

# %%
newdf.iloc[2,2]#access col by index
# Out:
# 'akola'

# %%
newdf
# Out:
#       name  marks      city
# 0    harry     92  malkapur
# 1    rohen     42      pune
# 2    karan    100     akola
# 3  shubham     75    mumbai

# %%
newdf.drop(0)#drop row
# Out:
#       name  marks    city
# 1    rohen     42    pune
# 2    karan    100   akola
# 3  shubham     75  mumbai

# %%
newdf.drop(['name'],axis=1)#drop column
# Out:
#    marks      city
# 0     92  malkapur
# 1     42      pune
# 2    100     akola
# 3     75    mumbai

# %%
newdf.head(2)
# Out:
#     name  marks      city
# 0  harry     92  malkapur
# 1  rohen     42      pune

# %%
newdf.reset_index()
# Out:
#    index     name  marks      city
# 0      0    harry     92  malkapur
# 1      1    rohen     42      pune
# 2      2    karan    100     akola
# 3      3  shubham     75    mumbai

# %%
newdf.reset_index(drop=True) #to reset
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-27ca4426d134> in <module>
# ----> 1 newdf.reset_index(drop=True) #to reset
#
# NameError: name 'newdf' is not defined

# %%
print("hell")
# Out:
# hell
